# %%
# import cell
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# import and inspect data
data = pd.read_csv("all_data.csv")
data.rename(columns={"Life expectancy at birth (years)":"life"},inplace= True)
data
# Out:
#      Country  Year  life           GDP
# 0      Chile  2000  77.3  7.786093e+10
# 1      Chile  2001  77.3  7.097992e+10
# 2      Chile  2002  77.8  6.973681e+10
# 3      Chile  2003  77.9  7.564346e+10
# 4      Chile  2004  78.0  9.921039e+10
# ..       ...   ...   ...           ...
# 91  Zimbabwe  2011  54.9  1.209845e+10
# 92  Zimbabwe  2012  56.6  1.424249e+10
# 93  Zimbabwe  2013  58.0  1.545177e+10
# 94  Zimbabwe  2014  59.2  1.589105e+10
# 95  Zimbabwe  2015  60.7  1.630467e+10
#
# [96 rows x 4 columns]

# %% [markdown]
# ### length of dataset

# %%
data.Country.value_counts()
data.Year.value_counts()
len(data.life)
# Out:
# 96

# %% [markdown]
# ### countries spread by life expectancy

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data = data, x ="Country",y = "life")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='life'>

# %% [markdown]
# ## vizualizing the data

# %%
sns.set_palette("Paired")
plt.figure(figsize= (20,20))
a=1
hmm = data["Country"].unique()
for country in hmm:
    plt.subplot(2,3,a)
    data1 = data[data.Country == country]
    sns.kdeplot(data = data1, x ="life")
    plt.title(country)
    plt.xlabel(country +" life expectancy")
    a+=1
    
plt.show()
# hmm = data.Country.unique().tolist()

# %%
plt.figure(figsize= (20,20))
a=1
hmm = data["Country"].unique()
for country in hmm:
    plt.subplot(2,3,a)
    data1 = data[data.Country == country]
    plt.plot( data1.Year,data1.life)
    plt.title(country)
    plt.xlabel(country +" life expectancy")
    a+=1
    
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data = data, x ="Country",y = "GDP")
plt.title("Gdp by country")
# Out:
# Text(0.5, 1.0, 'Gdp by country')

# %%
plt.figure(figsize= (20,20))
a=1
hmm = data["Country"].unique()
for country in hmm:
    plt.subplot(3,2,a)
    data1 = data[data.Country == country]
    plt.plot( data1.Year,data1.GDP)
    plt.title(country +" Gdp over the years")
    plt.xlabel("years")
    plt.ylabel("Gdp")
    a+=1
    
plt.show()

# %%
plt.figure(figsize= (20,20))
a=1
hmm = data["Country"].unique()
for country in hmm:
    plt.subplot(3,2,a)
    data1 = data[data.Country == country]
    sns.scatterplot( data = data1, x =data1.life,y = data1.GDP)
    plt.title(country +" Gdp vs life")
    plt.xlabel("life expectancy")
    plt.ylabel("Gdp")
    a+=1
    
plt.show()

# %%
plt.figure(figsize= (10,5))
data1 = data[data.Country == country]
sns.scatterplot( data = data, x ="life",y = "GDP",hue ="Country")
plt.title(" Gdp vs life")
plt.xlabel("life expectancy")
plt.ylabel("Gdp")

plt.show()

# %%
# check for association between gdp and life expectancy
from scipy.stats import pearsonr
print(pearsonr(data.life,data.GDP))
# Out:
# (0.343206748449156, 0.0006187129569469811)

# %%
for country in hmm:
    data1 = data[data.Country == country]
    print(pearsonr(data1.life,data1.GDP))
# Out:
# (0.9498766659254416, 1.865913974658531e-08)
# (0.9085255408648358, 1.1250985720700642e-06)
# (0.9326988982561268, 1.401881553404592e-07)
# (0.9322377167847081, 1.4686960248305143e-07)
# (0.9817092382430257, 1.7499709269099464e-11)
# (0.9661998955858777, 1.2358516366846197e-09)

# %%
plt.figure(figsize= (10,5))
sns.barplot(data = data, x= "Country", y = "life")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='life'>

# %%
data.groupby(["Country"]).life.mean().reset_index()
# Out:
#                     Country      life
# 0                     Chile  78.94375
# 1                     China  74.26250
# 2                   Germany  79.65625
# 3                    Mexico  75.71875
# 4  United States of America  78.06250
# 5                  Zimbabwe  50.09375
